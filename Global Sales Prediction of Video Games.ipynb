# %% [markdown]
# # <center>Prediction Of Global Sales Of Video Games using Machine Learning

# %% [markdown]
# <img src='videogame.jpg' width=1000 height=600>

# %% [markdown]
# <p> In this project we processing and exploring a large amount of data on video game sales.This dataset contains a list of video games with  sales greater than 100,000 copies. Each row in the dataset represents a game, whereas, each column contains different attributes.It contains   information regarding the sales of video games across various regions like North America, Europe, Japan and also globally, while also  giving information regarding the Names, Publishers,Genre and Platforms,Critic Score,Critic Count,User Score,User Count,Developer,Rating.</p>

# %% [markdown]
#  <p>The data set includes information about:<br>
#     Name - The name of the game.<br>
#     Platform- The platform on which the game was released.<br>
#     Year_of_Release- The year in which the game was released.<br>
#     Genre-The genre of the game.<br>
#     Publisher-The publisher of the game.<br>
#     NA_Sales, EU_Sales, JP_Sales , Other_Sales, Global_Sales - Sales made by a particular game in North America, Europe, Japan,                                                                 Other  regions and Globally (in millions).<br>
#     Critic_score - Aggregate score compiled by Metacritic staff.<br>
#     Critic_count - The number of critics used in coming up with the Critic_score. <br>
#     User_score -  Score by Metacritic's subscribers.<br>
#     User_count - Number of users who gave the user_score.<br>
#     Developer - Party responsible for creating the game.<br>
#     Rating -  The ESRB Rating.</p>

# %% [markdown]
# #### Importing Libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')
from sklearn.linear_model import LinearRegression,Ridge
from sklearn.preprocessing import LabelEncoder,StandardScaler
from sklearn.model_selection import cross_val_score,train_test_split
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor,AdaBoostRegressor,GradientBoostingRegressor
from sklearn.svm import LinearSVR
from sklearn.metrics import r2_score,mean_absolute_error,mean_squared_error

# %% [markdown]
# #### Loading  the dataset

# %%
df = pd.read_csv("./Video_Games_Sales.csv")
df
# Out:
#                                 Name Platform  Year_of_Release         Genre  \
# 0                         Wii Sports      Wii           2006.0        Sports
# 1                  Super Mario Bros.      NES           1985.0      Platform
# 2                     Mario Kart Wii      Wii           2008.0        Racing
# 3                  Wii Sports Resort      Wii           2009.0        Sports
# 4           Pokemon Red/Pokemon Blue       GB           1996.0  Role-Playing
# ...                              ...      ...              ...           ...
# 16714  Samurai Warriors: Sanada Maru      PS3           2016.0        Action
# 16715               LMA Manager 2007     X360           2006.0        Sports
# 16716        Haitaka no Psychedelica      PSV           2016.0     Adventure
# 16717               Spirits & Spells      GBA           2003.0      Platform
# 16718            Winning Post 8 2016      PSV           2016.0    Simulation
#
#           Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales  \
# 0          Nintendo     41.36     28.96      3.77         8.45         82.53
# 1          Nintendo     29.08      3.58      6.81         0.77         40.24
# 2          Nintendo     15.68     12.76      3.79         3.29         35.52
# 3          Nintendo     15.61     10.93      3.28         2.95         32.77
# 4          Nintendo     11.27      8.89     10.22         1.00         31.37
# ...             ...       ...       ...       ...          ...           ...
# 16714    Tecmo Koei      0.00      0.00      0.01         0.00          0.01
# 16715   Codemasters      0.00      0.01      0.00         0.00          0.01
# 16716  Idea Factory      0.00      0.00      0.01         0.00          0.01
# 16717       Wanadoo      0.01      0.00      0.00         0.00          0.01
# 16718    Tecmo Koei      0.00      0.00      0.01         0.00          0.01
#
#        Critic_Score  Critic_Count User_Score  User_Count Developer Rating
# 0              76.0          51.0          8       322.0  Nintendo      E
# 1               NaN           NaN        NaN         NaN       NaN    NaN
# 2              82.0          73.0        8.3       709.0  Nintendo      E
# 3              80.0          73.0          8       192.0  Nintendo      E
# 4               NaN           NaN        NaN         NaN       NaN    NaN
# ...             ...           ...        ...         ...       ...    ...
# 16714           NaN           NaN        NaN         NaN       NaN    NaN
# 16715           NaN           NaN        NaN         NaN       NaN    NaN
# 16716           NaN           NaN        NaN         NaN       NaN    NaN
# 16717           NaN           NaN        NaN         NaN       NaN    NaN
# 16718           NaN           NaN        NaN         NaN       NaN    NaN
#
# [16719 rows x 16 columns]

# %% [markdown]
# #### Data exploration

# %%
df.head()
# Out:
#                        Name Platform  Year_of_Release         Genre Publisher  \
# 0                Wii Sports      Wii           2006.0        Sports  Nintendo
# 1         Super Mario Bros.      NES           1985.0      Platform  Nintendo
# 2            Mario Kart Wii      Wii           2008.0        Racing  Nintendo
# 3         Wii Sports Resort      Wii           2009.0        Sports  Nintendo
# 4  Pokemon Red/Pokemon Blue       GB           1996.0  Role-Playing  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales  Critic_Score  \
# 0     41.36     28.96      3.77         8.45         82.53          76.0
# 1     29.08      3.58      6.81         0.77         40.24           NaN
# 2     15.68     12.76      3.79         3.29         35.52          82.0
# 3     15.61     10.93      3.28         2.95         32.77          80.0
# 4     11.27      8.89     10.22         1.00         31.37           NaN
#
#    Critic_Count User_Score  User_Count Developer Rating
# 0          51.0          8       322.0  Nintendo      E
# 1           NaN        NaN         NaN       NaN    NaN
# 2          73.0        8.3       709.0  Nintendo      E
# 3          73.0          8       192.0  Nintendo      E
# 4           NaN        NaN         NaN       NaN    NaN

# %%
df.sample(20)
# Out:
#                                        Name Platform  Year_of_Release  \
# 7120                     New Carnival Games       DS           2010.0
# 9927        Love Live! School Idol Paradise      PSV           2014.0
# 613                            Perfect Dark      N64           2000.0
# 12905          Shin Sangoku Musou 5 Empires      PSP           2010.0
# 6188          Cabela's Big Game Hunter 2012     X360           2011.0
# 1177              Pro Evolution Soccer 2010      PS2           2009.0
# 5418                              The Shoot      PS3           2010.0
# 8826                    World League Soccer     SNES           1991.0
# 5472              Kelly Slater's Pro Surfer      PS2           2002.0
# 13212                             Baku Baku      SAT           1995.0
# 10944                    Shin Megami Tensei       PS           2001.0
# 3877                     Way of the Samurai      PS2           2002.0
# 15800                Monster High 13 Wishes      3DS           2013.0
# 1364             Medal of Honor: Warfighter      PS3           2012.0
# 2363   Dissidia 012: Duodecim Final Fantasy      PSP           2011.0
# 16694                        Pony Friends 2       PC           2009.0
# 10456         Digimon Story: Lost Evolution       DS           2010.0
# 2173                  Driver: San Francisco      PS3           2011.0
# 2707              True Crime: New York City      PS2           2005.0
# 7606                             Famista 64      N64              NaN
#
#               Genre                     Publisher  NA_Sales  EU_Sales  \
# 7120           Misc          Take-Two Interactive      0.16      0.05
# 9927           Misc                Kadokawa Games      0.00      0.00
# 613          Action                      Nintendo      1.55      0.75
# 12905        Action                    Tecmo Koei      0.00      0.00
# 6188         Sports                    Activision      0.24      0.02
# 1177         Sports  Konami Digital Entertainment      0.10      0.18
# 5418        Shooter   Sony Computer Entertainment      0.13      0.15
# 8826         Sports                     Imagineer      0.00      0.00
# 5472         Sports                    Activision      0.16      0.13
# 13212        Puzzle                          Sega      0.00      0.00
# 10944  Role-Playing                         Atlus      0.00      0.00
# 3877         Action             Eidos Interactive      0.13      0.10
# 15800        Action                  Little Orbit      0.00      0.02
# 1364         Action               Electronic Arts      0.48      0.62
# 2363       Fighting                   Square Enix      0.21      0.12
# 16694    Simulation             Eidos Interactive      0.00      0.01
# 10456  Role-Playing            Namco Bandai Games      0.00      0.00
# 2173         Racing                       Ubisoft      0.24      0.52
# 2707         Action                    Activision      0.57      0.02
# 7606         Sports            Namco Bandai Games      0.00      0.00
#
#        JP_Sales  Other_Sales  Global_Sales  Critic_Score  Critic_Count  \
# 7120       0.00         0.02          0.22           NaN           NaN
# 9927       0.12         0.00          0.12           NaN           NaN
# 613        0.16         0.06          2.52           NaN           NaN
# 12905      0.05         0.00          0.05           NaN           NaN
# 6188       0.00         0.02          0.28           NaN           NaN
# 1177       0.12         1.16          1.57           NaN           NaN
# 5418       0.01         0.05          0.34          60.0          39.0
# 8826       0.15         0.00          0.15           NaN           NaN
# 5472       0.00         0.04          0.33          77.0          19.0
# 13212      0.05         0.00          0.05           NaN           NaN
# 10944      0.09         0.01          0.09           NaN           NaN
# 3877       0.25         0.03          0.51          74.0          22.0
# 15800      0.00         0.00          0.02           NaN           NaN
# 1364       0.06         0.26          1.41          55.0          22.0
# 2363       0.46         0.08          0.88          78.0          52.0
# 16694      0.00         0.00          0.01           NaN           NaN
# 10456      0.10         0.00          0.10           NaN           NaN
# 2173       0.01         0.18          0.95          79.0          53.0
# 2707       0.07         0.09          0.76           NaN           NaN
# 7606       0.17         0.03          0.20           NaN           NaN
#
#       User_Score  User_Count             Developer Rating
# 7120         tbd         NaN       Cat Daddy Games      E
# 9927         NaN         NaN                   NaN    NaN
# 613          NaN         NaN                   NaN    NaN
# 12905        NaN         NaN                   NaN    NaN
# 6188         tbd         NaN            Activision      T
# 1177         8.1        15.0                Konami      E
# 5418         6.2        11.0        Cohort Studios      T
# 8826         NaN         NaN                   NaN    NaN
# 5472         8.4        15.0              Treyarch      E
# 13212        NaN         NaN                   NaN    NaN
# 10944        NaN         NaN                   NaN    NaN
# 3877         8.2        19.0               Acquire      M
# 15800        tbd         NaN  Game Machine Studios      E
# 1364           6       250.0          Danger Close      M
# 2363         8.3       144.0           Square Enix      T
# 16694        NaN         NaN                   NaN    NaN
# 10456        NaN         NaN                   NaN    NaN
# 2173         7.7       114.0   Ubisoft Reflections      T
# 2707         NaN         NaN                   NaN    NaN
# 7606         NaN         NaN                   NaN    NaN

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16719 entries, 0 to 16718
# Data columns (total 16 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Name             16717 non-null  object
#  1   Platform         16719 non-null  object
#  2   Year_of_Release  16450 non-null  float64
#  3   Genre            16717 non-null  object
#  4   Publisher        16665 non-null  object
#  5   NA_Sales         16719 non-null  float64
#  6   EU_Sales         16719 non-null  float64
#  7   JP_Sales         16719 non-null  float64
#  8   Other_Sales      16719 non-null  float64
#  9   Global_Sales     16719 non-null  float64
#  10  Critic_Score     8137 non-null   float64
#  11  Critic_Count     8137 non-null   float64
#  12  User_Score       10015 non-null  object
#  13  User_Count       7590 non-null   float64
#  14  Developer        10096 non-null  object
#  15  Rating           9950 non-null   object
# dtypes: float64(9), object(7)
# memory usage: 2.0+ MB

# %%
df.describe()
# Out:
#        Year_of_Release      NA_Sales      EU_Sales      JP_Sales  \
# count     16450.000000  16719.000000  16719.000000  16719.000000
# mean       2006.487356      0.263330      0.145025      0.077602
# std           5.878995      0.813514      0.503283      0.308818
# min        1980.000000      0.000000      0.000000      0.000000
# 25%        2003.000000      0.000000      0.000000      0.000000
# 50%        2007.000000      0.080000      0.020000      0.000000
# 75%        2010.000000      0.240000      0.110000      0.040000
# max        2020.000000     41.360000     28.960000     10.220000
#
#         Other_Sales  Global_Sales  Critic_Score  Critic_Count    User_Count
# count  16719.000000  16719.000000   8137.000000   8137.000000   7590.000000
# mean       0.047332      0.533543     68.967679     26.360821    162.229908
# std        0.186710      1.547935     13.938165     18.980495    561.282326
# min        0.000000      0.010000     13.000000      3.000000      4.000000
# 25%        0.000000      0.060000     60.000000     12.000000     10.000000
# 50%        0.010000      0.170000     71.000000     21.000000     24.000000
# 75%        0.030000      0.470000     79.000000     36.000000     81.000000
# max       10.570000     82.530000     98.000000    113.000000  10665.000000

# %%
df.shape
# Out:
# (16719, 16)

# %% [markdown]
# #### Checking the null percentage

# %%
df.isnull().mean()*100
# Out:
# Name                0.011962
# Platform            0.000000
# Year_of_Release     1.608948
# Genre               0.011962
# Publisher           0.322986
# NA_Sales            0.000000
# EU_Sales            0.000000
# JP_Sales            0.000000
# Other_Sales         0.000000
# Global_Sales        0.000000
# Critic_Score       51.330821
# Critic_Count       51.330821
# User_Score         40.098092
# User_Count         54.602548
# Developer          39.613613
# Rating             40.486871
# dtype: float64

# %%
df.dropna(inplace=True)

# %% [markdown]
# ##### Checking the duplicate values

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ## Explorartory Data Analysis

# %% [markdown]
# ### Univariate analysis

# %% [markdown]
# ##### Histogram

# %%
for i in df.columns:
    if df[i].dtype != "object":
        sns.histplot(x=df[i])
        plt.show()

# %% [markdown]
# ##### KDE plot

# %%
for i in df.columns:
    if df[i].dtype !="object":
        sns.kdeplot(x=df[i])
        plt.show()

# %% [markdown]
# ##### Box Plot

# %%
for i in df.columns:
    if df[i].dtype !="object":
        sns.boxplot(y=df[i])
        plt.show()

# %% [markdown]
# ##### Outliers are present , so we have to treat the outliers

# %%
def outlier_limit(col):
    Q3,Q1 = np.nanpercentile(col,[75,25])
    IQR = Q3 - Q1
    UL = Q3+1.5*IQR
    LL = Q1-1.5*IQR
    return UL,LL

# %%
for column in df.columns:
    if df[column].dtype != "object":
        UL,LL = outlier_limit(df[column])
        df[column]=np.where((df[column]>UL) | (df[column]<LL),np.nan,df[column])

# %% [markdown]
# #####  Drop the null values

# %%
df.dropna(inplace=True)

# %% [markdown]
# ##### After outlier treatment again plot the Boxplot

# %%
df.drop(columns="JP_Sales",inplace=True)

# %%
for i in df.columns:
    if df[i].dtype != "object":
        sns.boxplot(y=df[i])
        plt.show()

# %% [markdown]
# ### Multivariate Analysis

# %% [markdown]
# #####  Bar Chart

# %%
plt.figure(figsize=(12,6))
plt.title('Platform VS Global Sales')
sns.barplot(x= df['Platform'], y= df['Global_Sales']);

# %% [markdown]
# ### Inference:
# #### We can see that top selling games are for PS3 and lowest selling is PC

# %%
plt.figure(figsize=(9,6))
plt.title('Rating VS Global Sales')
sns.barplot(x=df['Rating'] , y=df['Global_Sales']);

# %% [markdown]
# ### Inference :
# #### Top selling game ratings belongs to E rating and lowest is of RP

# %%
plt.figure(figsize=(19,6))
plt.title('Year of Release VS Global Sales')
sns.barplot(x=df['Year_of_Release'], y=df['Global_Sales']);

# %%
plt.figure(figsize=(14,6))
sns.barplot(x=df["Genre"],y=df["Global_Sales"])
plt.title("Global sales vs Genre");

# %% [markdown]
# ##### Scatter Plot

# %%
sns.scatterplot(df,x="NA_Sales",y="Global_Sales",color="Black");

# %% [markdown]
# #### Pie Chart

# %%
explode=0.1,0.1,0.1,0.1,0
df.Rating.value_counts().plot.pie(autopct='%1.2f%%',explode=explode);

# %% [markdown]
# #### Line Chart

# %%
sns.lineplot(df,x="Year_of_Release",y="Global_Sales",color="red",ci=None);
plt.title("Global sales vs Year Of Release");

# %% [markdown]
# #### Pair Plot

# %%
sns.pairplot(df,hue="Global_Sales");

# %% [markdown]
# #### Perform Label Encoding to convert the categorical variables

# %%
le = LabelEncoder()
df["Name"]=le.fit_transform(df["Name"])
df["Platform"]=le.fit_transform(df["Platform"])
df["Genre"]=le.fit_transform(df["Genre"])
df["Publisher"]=le.fit_transform(df["Publisher"])
df["User_Score"]=le.fit_transform(df["User_Score"])
df["Developer"]=le.fit_transform(df["Developer"])
df["Rating"]=le.fit_transform(df["Rating"])

# %% [markdown]
# ##### Check the correlation with the target variable "Global Sales"

# %%
sns.heatmap(df.corr()[["Global_Sales"]].sort_values(by="Global_Sales",ascending=False),vmin=-1,vmax=1,annot=True,cmap="RdBu_r");

# %% [markdown]
# #### Take the only columns which have good correlation with the target variable "Global Sales"

# %%
x = df[["NA_Sales","EU_Sales","Other_Sales","Critic_Count","Critic_Score"]].values
y = df[["Global_Sales"]].values

# %% [markdown]
# ###### Feature Scaling

# %%
sc = StandardScaler()

# %%
x = sc.fit_transform(x)

# %% [markdown]
# ##### Model Building

# %%
models ={
    "LinearRegression":LinearRegression(),
    "Ridge":Ridge(),
    "AdaBoostRegressor":AdaBoostRegressor(),
    "GradientBoostingRegressor":GradientBoostingRegressor(),
    "LinearSVR":LinearSVR(),
    "DecisionTreeRegressor":DecisionTreeRegressor(),
    "RandomForestRegressor":RandomForestRegressor()
}

# %%
for name,model in models.items():
    scores = cross_val_score(model,x,y,scoring="neg_mean_squared_error",cv=10,n_jobs=-1)
    print("Cross validation model : {} ".format(name))
    rmse = np.sqrt(-scores)
    rmse_avg = np.mean(rmse)
    print("Average RMSE : ",rmse_avg)
    print("*"*100)
# Out:
# Cross validation model : LinearRegression
# Average RMSE :  0.006899428856893659
# ****************************************************************************************************
# Cross validation model : Ridge
# Average RMSE :  0.006906350385334402
# ****************************************************************************************************
# Cross validation model : AdaBoostRegressor
# Average RMSE :  0.10278721768297325
# ****************************************************************************************************
# Cross validation model : GradientBoostingRegressor
# Average RMSE :  0.04526106523068992
# ****************************************************************************************************
# Cross validation model : LinearSVR
# Average RMSE :  0.007181033887858822
# ****************************************************************************************************
# Cross validation model : DecisionTreeRegressor
# Average RMSE :  0.06557657750384051
# ****************************************************************************************************
# Cross validation model : RandomForestRegressor
# Average RMSE :  0.05652935294558549
# ****************************************************************************************************

# %% [markdown]
# ##### Since the Linear Regression model has the minimum rmse value, we will select it

# %%
model = LinearRegression()

# %% [markdown]
# ##### Split the datase into training and testing data

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=0)

# %% [markdown]
# ###### Fit the model with the training data

# %%
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %% [markdown]
# ###### We can check the efficiency of the model

# %%
training_score = model.score(x_train,y_train)*100
testing_score = model.score(x_test,y_test)*100
R2_score = r2_score(y_test,model.predict(x_test))*100
mae = mean_absolute_error(y_test,model.predict(x_test))
mse = mean_squared_error(y_test,model.predict(x_test))
rmse = np.sqrt(mse)
print("r2score: ",R2_score)
print("training_score: ",training_score)
print("testing_score: ",testing_score)
print("mae: ",mae)
print("mse: ",mse)
# Out:
# r2score:  99.93238132643387
# training_score:  99.93707259292214
# testing_score:  99.93238132643387
# mae:  0.004972802851224321
# mse:  5.239998386719016e-05

# %% [markdown]
# ###### Predicting values using the model

# %%
y_pred=model.predict(x)

# %% [markdown]
# ###### After predicting we can compare it with the actual value

# %%
OUTPUT = pd.DataFrame(zip(y,y_pred),columns=("ACTUAL","PREDICTED"),dtype="float")
OUTPUT.head()
# Out:
#    ACTUAL  PREDICTED
# 0    1.42   1.409969
# 1    1.41   1.410897
# 2    1.37   1.370294
# 3    1.36   1.371565
# 4    1.35   1.339776

# %% [markdown]
# ###### Scatter Plot

# %%
sns.scatterplot(OUTPUT,x="ACTUAL",y="PREDICTED",color="Purple");

# %%
model.score(x,y)
# Out:
# 0.9993608572461234
